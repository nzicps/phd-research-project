# %% [markdown]
# # 09 — Robustness Checks
#
# Alternative specifications and sensitivity analysis.
#
# This notebook is a placeholder scaffold — populate it once the primary specification in `08_propensity_score.ipynb` is finalised.

# %%
import sys
sys.path.insert(0, '..')

from src.data_loader import load_data
from src.cleaning import standardise_columns
from src.models import fit_ols, model_summary_table

df = standardise_columns(load_data('synthetic'))

# %% [markdown]
# ## Alternative specification 1: regression adjustment (no matching)

# %%
model = fit_ols(df, 'income ~ chronic_condition + age + C(sex) + C(education)')
model_summary_table(model)

# %% [markdown]
# ## Alternative specification 2 (TODO)
#
# - Alternative covariate set
# - Alternative treatment definition
# - Placebo outcome test
