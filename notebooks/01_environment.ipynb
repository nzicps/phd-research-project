# %% [markdown]
# # 01 — Environment Test
#
# Confirm the research environment is working, and that the data-access layer can load a dataset.

# %%
import sys
sys.path.insert(0, '..')  # so `import src...` works when running from notebooks/

import pandas as pd
import numpy as np
import scipy
import statsmodels
import sklearn
import matplotlib
import seaborn
import duckdb

print('PhD research environment is working.')

# %% [markdown]
# ## Load data through the project's own data interface
#
# The notebook doesn't need to know whether the data is synthetic or (eventually) approved IDI/LBD data — see `src/data_loader.py`.

# %%
from src.data_loader import load_data

df = load_data('synthetic')
df.head()

# %%
df.info()

# %% [markdown]
# If the cells above ran without error and you can see the first rows of the synthetic dataset, your environment and data interface are both working. Continue to `02_data_structure.ipynb`.
